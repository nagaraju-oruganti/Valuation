# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %cd ../src
# Out:
# /Users/Oruganti/Library/CloudStorage/GoogleDrive-finmetrics0@gmail.com/My Drive/Valuation/src

# %%
from helper_utils import RandomDistributions as Dist
dist = Dist()

# %%
dist.construct_normal_samples(mean = 0, std_dev = 1, sample_size = 50000)
sns.histplot(x = dist.normal_samples, kde = True)
plt.show()

# %%
dist.construct_skewnorm_samples(a = -3, mean = 3, std_dev = 1, sample_size = 50000)
sns.histplot(x = dist.skewnorm_samples, kde = True)
plt.show()

# %%
np.median(dist.skewnorm_samples)
# Out:
# 2.3363946261632904

# %%
dist.construct_uniform_samples(low = 2, high = 6, sample_size = 50000)
sns.histplot(x = dist.uniform_samples, kde = True)
plt.show()

# %%
dist.construct_triangular_samples(low = 0, high = 6, peak = 3, sample_size = 50000)
sns.histplot(x = dist.triang_samples, kde = True)
plt.show()
